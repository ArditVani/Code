# %% [markdown]
#  # Comprehensions & generators
#  - list comprehensions
#  - list comprehensions inclusief control flow
#  - Dict comprehensions
#  - Generators

# %% [markdown]
# ## 14.1 list comprehensions
# - Voer onderstaande cel uit om storedata aan te maken
#
# ---
# - Execute the cell below to create store data

# %%
import pandas as pd
import numpy as np
storedata = pd.read_csv('storedata_clean.csv',sep=";")
storedata.rename(columns={'Profit': 'Turnover'}, inplace=True)
storedata.head()
# Out:
#                             Town Country  Store ID Manager name  Staff  \
# 0   Swinton (Greater Manchester)      UK      1437        Roger      9
# 1                       Stamford      UK      1544         Ella      8
# 2                        Skipton      UK      2039    Valentina      2
# 3                       Stratton      UK      2055      Antonia      7
# 4                     Shepperton      UK      2141      Gabriel      7
#
#    Floor Space  Window Car park  Demographic score         Location  \
# 0        18526     121      Yes                 10      Retail Park
# 1        18569     121      Yes                 11  Shopping Centre
# 2        12288     105       No                 12      Retail Park
# 3        17092     117       No                 14      High Street
# 4        11307     103       No                 18      Retail Park
#
#    40min population  30 min population  20 min population  10 min population  \
# ...

# %% [markdown]
# - Maak een nieuwe kolom 'to_eur' in storedata met daarin de omzet in EUR.
# - Pas hiervoor een list comprehension toe om de getallen in de 'Turnover' kolom om te rekenen van GBP naar EUR. Zoek de actuele wisselkoers op, op het internet.
# - Zorg ervoor dat het integere getallen zijn.
# - Controleer of de nieuwe kolom juist is aangemaakt.
#
# ---
# - Create a new column 'to_eur' in storedata containing the turnover in EUR.
# - Apply a list comprehension to convert the numbers in the 'Turnover' column from GBP to EUR. Look up the current exchange rate on the internet.
# - Make sure they are integer numbers.
# - Check whether the new column has been created correctly.

# %%
#%%timeit
storedata['to_eur']= storedata['Turnover']*1.14
storedata
# Out:
#                               Town Country  Store ID Manager name  Staff  \
# 0     Swinton (Greater Manchester)      UK      1437        Roger      9
# 1                         Stamford      UK      1544         Ella      8
# 2                          Skipton      UK      2039    Valentina      2
# 3                         Stratton      UK      2055      Antonia      7
# 4                       Shepperton      UK      2141      Gabriel      7
# ..                             ...     ...       ...          ...    ...
# 131                 South Benfleet      UK     96853      Vitória      7
# 132                          Sandy      UK     96858       Matías      6
# 133                      Sheerness      UK     98062      Gustavo      7
# 134                        Salford      UK     98923       Rafael      6
# 135                     Stapleford      UK     99854          Lea      9
#
#      Floor Space  Window Car park  Demographic score         Location  ...  \
# ...

# %% [markdown]
# - Maak een nieuwe kolom 'to_perf' met behulp van een list comprehension.
# - Zorg ervoor dat in deze kolom het volgende staat:
#     - 'good' als de omzet in de kolom to_eur hoger is dan 4000000
#     - 'bad' als de omzet in de kolom to_eur lager dan of gelijk aan 4000000 is.
#
#  ---
# - Create a new column 'to_perf' using a list comprehension.
# - Make sure this column contains the following:
#  - 'good' if the turnover in the column to_eur is higher than 4000000
#  - 'bad' if the revenue in the to_eur column is less than or equal to 4000000.

# %%
#%%timeit
storedata['to_eur'] =[int(x * 1.14) for x in storedata['Turnover']]
storedata
# Out:
#                               Town Country  Store ID Manager name  Staff  \
# 0     Swinton (Greater Manchester)      UK      1437        Roger      9
# 1                         Stamford      UK      1544         Ella      8
# 2                          Skipton      UK      2039    Valentina      2
# 3                         Stratton      UK      2055      Antonia      7
# 4                       Shepperton      UK      2141      Gabriel      7
# ..                             ...     ...       ...          ...    ...
# 131                 South Benfleet      UK     96853      Vitória      7
# 132                          Sandy      UK     96858       Matías      6
# 133                      Sheerness      UK     98062      Gustavo      7
# 134                        Salford      UK     98923       Rafael      6
# 135                     Stapleford      UK     99854          Lea      9
#
#      Floor Space  Window Car park  Demographic score         Location  ...  \
# ...

# %%
#%%timeit
list_for = []
for x in storedata['Turnover']:
    list_for.append(x + 1.14)
storedata['to_eur_for'] = list_for
storedata
# Out:
#                               Town Country  Store ID Manager name  Staff  \
# 0     Swinton (Greater Manchester)      UK      1437        Roger      9
# 1                         Stamford      UK      1544         Ella      8
# 2                          Skipton      UK      2039    Valentina      2
# 3                         Stratton      UK      2055      Antonia      7
# 4                       Shepperton      UK      2141      Gabriel      7
# ..                             ...     ...       ...          ...    ...
# 131                 South Benfleet      UK     96853      Vitória      7
# 132                          Sandy      UK     96858       Matías      6
# 133                      Sheerness      UK     98062      Gustavo      7
# 134                        Salford      UK     98923       Rafael      6
# 135                     Stapleford      UK     99854          Lea      9
#
#      Floor Space  Window Car park  Demographic score         Location  ...  \
# ...

# %%
new_list = []
for to in storedata['to_eur']:
    if to > 4000000:
        new_list.append('good')
    else:
        new_list.append('bad')
storedata['to_preformance'] = new_list
storedata
# Out:
#                               Town Country  Store ID Manager name  Staff  \
# 0     Swinton (Greater Manchester)      UK      1437        Roger      9
# 1                         Stamford      UK      1544         Ella      8
# 2                          Skipton      UK      2039    Valentina      2
# 3                         Stratton      UK      2055      Antonia      7
# 4                       Shepperton      UK      2141      Gabriel      7
# ..                             ...     ...       ...          ...    ...
# 131                 South Benfleet      UK     96853      Vitória      7
# 132                          Sandy      UK     96858       Matías      6
# 133                      Sheerness      UK     98062      Gustavo      7
# 134                        Salford      UK     98923       Rafael      6
# 135                     Stapleford      UK     99854          Lea      9
#
#      Floor Space  Window Car park  Demographic score         Location  ...  \
# ...

# %%
storedata['to_preformance'] = ['good'if to > 4000000 else 'bad' for to in storedata['to_eur']]
storedata
# Out:
#                               Town Country  Store ID Manager name  Staff  \
# 0     Swinton (Greater Manchester)      UK      1437        Roger      9
# 1                         Stamford      UK      1544         Ella      8
# 2                          Skipton      UK      2039    Valentina      2
# 3                         Stratton      UK      2055      Antonia      7
# 4                       Shepperton      UK      2141      Gabriel      7
# ..                             ...     ...       ...          ...    ...
# 131                 South Benfleet      UK     96853      Vitória      7
# 132                          Sandy      UK     96858       Matías      6
# 133                      Sheerness      UK     98062      Gustavo      7
# 134                        Salford      UK     98923       Rafael      6
# 135                     Stapleford      UK     99854          Lea      9
#
#      Floor Space  Window Car park  Demographic score         Location  ...  \
# ...

# %%
storedata['Country'].unique()
# Out:
# array(['UK', 'France'], dtype=object)

# %%
storedata['to_eur'] = [int(x * 1.14) if y == 'UK' else x for x, y in zip(storedata['Turnover'], storedata['Country'])]
storedata
# Out:
#                               Town Country  Store ID Manager name  Staff  \
# 0     Swinton (Greater Manchester)      UK      1437        Roger      9
# 1                         Stamford      UK      1544         Ella      8
# 2                          Skipton      UK      2039    Valentina      2
# 3                         Stratton      UK      2055      Antonia      7
# 4                       Shepperton      UK      2141      Gabriel      7
# ..                             ...     ...       ...          ...    ...
# 131                 South Benfleet      UK     96853      Vitória      7
# 132                          Sandy      UK     96858       Matías      6
# 133                      Sheerness      UK     98062      Gustavo      7
# 134                        Salford      UK     98923       Rafael      6
# 135                     Stapleford      UK     99854          Lea      9
#
#      Floor Space  Window Car park  Demographic score         Location  ...  \
# ...

# %% [markdown]
# - Breid bovenstaande list comprehension uit met een extra voorwaarde:
#    - 'good' als de omzet in de kolom to_eur hoger is dan 4000000
#    - 'okay' als de omzet in de kolom to_eur hoger is dan 3500000
#    - 'bad' als de omzet in de kolom to_eur lager dan of gelijk aan 3500000 is.
#
# Hint: in een list comprehension kun je niet gebruik maken van elif, maar wel van de combinatie if en else.
#
# ---
# - Extend the above list comprehension with an extra condition:
#     - 'good' if the turnover in the column to_eur is higher than 4000000
#     - 'okay' if the turnover in the column to_eur is higher than 3500000
#     - 'bad' if the turnover in the column to_eur is less than or equal to 3500000.
#
# Hint: in a list comprehension you cannot use elif, but you can use the combination if and else.

# %%
storedata['to_preformance'] = ['good' if to > 4000000 else 'okay' if to > 3500000 else 'bad' for to in storedata['to_eur']]
storedata
# Out:
#                               Town Country  Store ID Manager name  Staff  \
# 0     Swinton (Greater Manchester)      UK      1437        Roger      9
# 1                         Stamford      UK      1544         Ella      8
# 2                          Skipton      UK      2039    Valentina      2
# 3                         Stratton      UK      2055      Antonia      7
# 4                       Shepperton      UK      2141      Gabriel      7
# ..                             ...     ...       ...          ...    ...
# 131                 South Benfleet      UK     96853      Vitória      7
# 132                          Sandy      UK     96858       Matías      6
# 133                      Sheerness      UK     98062      Gustavo      7
# 134                        Salford      UK     98923       Rafael      6
# 135                     Stapleford      UK     99854          Lea      9
#
#      Floor Space  Window Car park  Demographic score         Location  ...  \
# ...

# %% [markdown]
# ## 14.2 Dict comprehensions
# - Pas een dict comprehension toe om de dictionary to_gbp_eur te maken met daarin de GBP omzetten ('Turnover') als 'keys' en de EUR omzetten als 'value'.
# - Print to_gbp_eur
#
# ---
# - Apply a dict comprehension to create the dictionary to_gbp_eur containing the GBP converts ('Turnover') as 'keys' and the EUR converts as 'value'.
# - Print to_gbp_eur

# %%
gbp_eur = 1.15
to_gbp_eur = {x:round(x * gbp_eur) for x in storedata['Turnover']}
print(to_gbp_eur)
# Out:
# {3410865: 3922495, 4034051: 4639159, 2297810: 2642482, 2398990: 2758838, 2288235: 2631470, 3058134: 3516854, 2793160: 3212134, 3345936: 3847826, 3117205: 3584786, 3153278: 3626270, 3056804: 3515325, 1801619: 2071862, 3797953: 4367646, 3138911: 3609748, 2724068: 3132678, 2382751: 2740164, 3321899: 3820184, 2803867: 3224447, 3640627: 4186721, 3075352: 3536655, 3491993: 4015792, 3252148: 3739970, 3041618: 3497861, 3737466: 4298086, 4217291: 4849885, 2008363: 2309617, 3516397: 4043857, 3957233: 4550818, 2942839: 3384265, 2242288: 2578631, 2616387: 3008845, 2493975: 2868071, 2203994: 2534593, 2458785: 2827603, 4253984: 4892082, 4185306: 4813102, 4160531: 4784611, 3100521: 3565599, 3246954: 3733997, 2085733: 2398593, 3741911: 4303198, 2506748: 2882760, 2393869: 2752949, 4137224: 4757808, 3572475: 4108346, 3121837: 3590113, 2799074: 3218935, 2707402: 3113512, 4176642: 4803138, 1829621: 2104064, 2681110: 3083276, 2411437: 2773153, 4300537: 4945618, 3758014: 4321716, 2234201: 2569331, 2342229
# ...

# %% [markdown]
# ## 14.3 Generators
# - Maak een generator object floor_size dat 'big' bevat als de winkeloppervlakte ('Floor Space') groter of gelijk aan 15000 is en 'small' bevat als de winkeloppervlakte lager is dan 15000.
# - Print het type van floor_size
# - Print de eerste 3 elementen in floor_size door de next() functie toe te passen.
# - Print de andere elementen met behulp van een for loop.
#
# ---
#
# - Create a generator object floor_size that contains 'big' if the floor space is greater than or equal to 15000 and contains 'small' if the floor space is less than 15000.
# - Print the type of floor_size
# - Print the first 3 elements in floor_size by applying the next() function.
# - Print the other elements using a for loop.

# %%
#%%timeit
floor_size = ('big' if fs > 15000 else 'small' for fs in storedata['Floor Space'])
floor_size
print(next(floor_size))
print(next(floor_size))
print(next(floor_size))
for size in floor_size:
    print(size)
# Out:
# big
# big
# small
# big
# small
# big
# small
# big
# small
# small
# small
# small
# big
# small
# small
# small
# small
# small
# big
# small
# big
# big
# big
# big
# big
# small
# small
# big
# big
# small
# big
# big
# big
# big
# big
# big
# small
# small
# big
# small
# big
# small
# small
# big
# small
# small
# small
# small
# big
# small
# small
# small
# small
# big
# small
# small
# small
# small
# small
# big
# small
# big
# big
# small
# small
# big
# big
# small
# small
# big
# small
# big
# small
# small
# big
# small
# small
# big
# small
# small
# big
# small
# small
# big
# small
# small
# small
# big
# big
# big
# small
# big
# small
# big
# big
# small
# big
# big
# big
# big
# small
# small
# big
# big
# small
# big
# small
# big
# big
# big
# small
# big
# big
# big
# small
# big
# big
# big
# small
# small
# small
# small
# big
# big
# big
# big
# small
# small
# small
# small
# small
# small
# small
# big
# big
# small

# %% [markdown]
# - Waarom zou je een generator gebruiken in plaats van een een list comprehension?
#
# ---
# - Why use a generator instead of a list comprehension?

# %% [markdown]
# - Definieer de function big_small(col) die een generator object aanmaakt dat hetzelfde is als het generator object dat je hebt gemaakt in de vorige opdracht.
# - Gebruik een for loop die de elementen uit deze generator print als deze wordt uitgevoerd met de 'Floor Space' kolom als parameter.
#
# ---
# - Define the function big_small(col) which creates a generator object that is the same as the generator object you created in the previous assignment.
# - Use a for loop that prints the elements from this generator when executed with the 'Floor Space' column as parameter.
#
# Extra info over generators:
# https://www.freecodecamp.org/news/how-and-why-you-should-use-python-generators-f6fb56650888/#:~:text=Generators%20have%20been%20an%20important,%2C%20easy%2C%20and%20clean%20way.

# %%
def big_small(col):
    for size in col:
        if size >= 15000:
            yield 'big'
        else:
            yield 'small'            

for size in big_small(storedata['Floor Space']):
    print(size)
# Out:
# big
# big
# small
# big
# small
# big
# small
# big
# small
# small
# small
# small
# big
# small
# small
# small
# small
# small
# big
# small
# big
# big
# big
# big
# big
# small
# small
# big
# big
# small
# big
# big
# big
# big
# big
# big
# small
# small
# big
# small
# big
# small
# small
# big
# small
# small
# small
# small
# big
# small
# small
# small
# small
# big
# small
# small
# small
# small
# small
# big
# small
# big
# big
# small
# small
# big
# big
# small
# small
# big
# small
# big
# small
# small
# big
# small
# small
# big
# small
# small
# big
# small
# small
# big
# small
# small
# small
# big
# big
# big
# small
# big
# small
# big
# big
# small
# big
# big
# big
# big
# small
# small
# big
# big
# small
# big
# small
# big
# big
# big
# small
# big
# big
# big
# small
# big
# big
# big
# small
# small
# small
# small
# big
# big
# big
# big
# small
# small
# small
# small
# small
# small
# small
# big
# big
# small

# %% [markdown]
# ## 14.4 Comprehensions and pandas dataseries
# - Maak een nieuwe kolom 'Avg' aan met behulp van een list comprehension:
#     - 'above average' als het aantal medewerkers ('Staff') hoger is dan of gelijk is aan het gemiddeld aantal medewerkers.
#     - 'below average' als het aantal medewerkers ('Staff') lager is dan het gemiddeld aantal medewerkers.
#
# ---
# - Create a new column 'Avg' using a list comprehension:
#      - 'above average' if the number of employees ('Staff') is higher than or equal to the average number of employees.
#      - 'below average' if the number of employees ('Staff') is lower than the average number of employees.

# %%
st = storedata['Staff']
avg_check = ['above average' if number >= np.mean(st) else 'below average' for number in st ]
storedata['Avg']=avg_check
storedata.head()
# Out:
#                             Town Country  Store ID Manager name  Staff  \
# 0   Swinton (Greater Manchester)      UK      1437        Roger      9
# 1                       Stamford      UK      1544         Ella      8
# 2                        Skipton      UK      2039    Valentina      2
# 3                       Stratton      UK      2055      Antonia      7
# 4                     Shepperton      UK      2141      Gabriel      7
#
#    Floor Space  Window Car park  Demographic score         Location  ...  \
# 0        18526     121      Yes                 10      Retail Park  ...
# 1        18569     121      Yes                 11  Shopping Centre  ...
# 2        12288     105       No                 12      Retail Park  ...
# 3        17092     117       No                 14      High Street  ...
# 4        11307     103       No                 18      Retail Park  ...
#
#    Store age  Clearance space  Competition number  Competition score  \
# ...

# %% [markdown]
# ## 14.5 Data laden met een generator
#
# In the cell below you will find the code of an exercise from the data camp course Python Data Science Toolbox (Part 2):
# https://campus.datacamp.com/courses/python-data-science-toolbox-part-2/bringing-it-all-together-3?ex=8
#
# - Modify this code so that you can read the file 'storedata.csv' into a generator object in a similar way.
# - Hint: Also apply the readline() method for the while loop so that you skip the first line with the column headers.
# - Print the first 3 lines of the generator object.
#
# Text from data camp about generators:
#
# Generators allow users to lazily evaluate data. This concept of lazy evaluation is useful when you have to deal with very large datasets because it lets you generate values in an efficient manner by yielding only chunks of data at a time instead of the whole thing at once.
#
# In this exercise, you will define a generator function read_large_file() that produces a generator object which yields a single line from a file each time next() is called on it. Make sure the csv file 'storedata.csv' is in your current directory.
#
# Note that when you open a connection to a file, the resulting file object is already a generator! So out in the wild, you won't have to explicitly create generator objects in cases such as this. However, for pedagogical reasons, we are having you practice how to do this here with the read_large_file() function. Go for it!
#
# - Meer info over with/open: https://www.pythonforbeginners.com/files/with-statement-in-python

# %%
#Datacamp code:

# Define read_large_file()
def read_large_file(file_object):
    """A generator function to read a large file lazily."""

    # Loop indefinitely until the end of the file
    while True:

        # Read a line from the file: data
        data = file_object.readline()

        # Break if this is the end of the file
        if not data:
            break

        # Yield the line of data
        yield data

# Open a connection to the file
with open('world_dev_ind.csv') as file:

    # Create a generator object for the file: gen_file
    gen_file = read_large_file(file)

    # Print the first three lines of the file
    print(next(gen_file))
    print(next(gen_file))
    print(next(gen_file))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/12/xxbjr1293w98m0lcjvj_99h80000gn/T/ipykernel_1556/3022515917.py in <module>
#      19
#      20 # Open a connection to the file
# ---> 21 with open('world_dev_ind.csv') as file:
#      22
#      23     # Create a generator object for the file: gen_file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'world_dev_ind.csv'

# %% [markdown]
# - Pas de code uit onderstaande cel aan zodat je een dictionary krijgt met daarin het aantal unieke waardes uit de 'Staff' kolom.

# %%
#datacamp code:

# Initialize an empty dictionary: counts_dict
counts_dict = {}

# Open a connection to the file
with open('world_dev_ind.csv') as file:

    # Iterate over the generator from read_large_file()
    for line in read_large_file(file):

        row = line.split(',')
        first_col = row[0]

        if first_col in counts_dict.keys():
            counts_dict[first_col] += 1
        else:
            counts_dict[first_col] = 1

# Print            
print(counts_dict)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/12/xxbjr1293w98m0lcjvj_99h80000gn/T/ipykernel_1556/2943935510.py in <module>
#       5
#       6 # Open a connection to the file
# ----> 7 with open('world_dev_ind.csv') as file:
#       8
#       9     # Iterate over the generator from read_large_file()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'world_dev_ind.csv'
